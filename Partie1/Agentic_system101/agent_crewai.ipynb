# %%
from crewai import Agent
from crewai import Task

# %% [markdown]
# # **Mono Agent**

# %% [markdown]
# ## Définition des agents

# %%
from crewai import LLM 

llm = LLM(
    model="ollama/llama3.2:3b",
    base_url="http://localhost:11434"
)

# %%
senior_technical_writer = Agent(

    role="Senior Technical Writer",
    
    goal="""Craft clear, engaging, and well-structured
            technical content based on research findings""",
    
    backstory="""You are an experienced technical writer
                 with expertise in simplifying complex
                 concepts, structuring content for readability,
                 and ensuring accuracy in documentation.""",

    llm=llm,
                 
    verbose=True  # Enable logging for debugging
)

# %%
research_analyst = Agent(
    role="Senior Research Analyst",
    goal="""Find, analyze, and summarize information 
            from various sources to support technical 
            and business-related inquiries.""",
    backstory="""You are a skilled research analyst with expertise 
                 in gathering accurate data, identifying key trends, 
                 and presenting insights in a structured manner.""",
    llm=llm,
    verbose=True
)

# %%
code_reviewer = Agent(
    role="Senior Code Reviewer",
    goal="""Review code for bugs, inefficiencies, and 
            security vulnerabilities while ensuring adherence 
            to best coding practices.""",
    backstory="""You are a seasoned software engineer with years of 
                 experience in writing, reviewing, and optimizing 
                 production-level code in multiple programming languages.""",
    llm=llm,
    verbose=True
)

# %%
legal_reviewer = Agent(
    role="Legal Document Expert Reviewer",
    goal="""Review contracts and legal documents to 
            ensure compliance with applicable laws and 
            highlight potential risks.""",
    backstory="""You are a legal expert with deep knowledge 
                 of contract law, regulatory frameworks, 
                 and risk mitigation strategies.""",
    llm=llm,
    verbose=True
)

# %% [markdown]
# ## Définition des tâches

# %%
writing_task = Task(
    description="""Write a well-structured, engaging,
                   and technically accurate article
                   on {topic}.""",
    
    agent=senior_technical_writer, 
    
    
    expected_output="""A polished, detailed, and easy-to-read
                       article on the given topic.""",
)

# %% [markdown]
# ## Création d'une équipe

# %%
from crewai import Crew

crew = Crew(
    agents=[senior_technical_writer],
    tasks=[writing_task],
    verbose=True
)

response = crew.kickoff(inputs={"topic":"AI Agents"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: e26cecfa-ce03-42f1-822c-af798428487e                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Technical Writer                                                                                 │
# │                                                                                                                 │
# │  Task: Write a well-structured, engaging,                                                                       │
# │                     and technically accurate article                                                            │
# │                     on AI Agents.                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Technical Writer                                                                                 │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  AI Agents: The Future of Intelligent Machines                                                                  │
# │  =============================================================                                                  │
# │                                                                                                                 │
# │  Artificial intelligence (AI) has made tremendous progress in recent years, transforming the way we live and    │
# │  work. At the heart of this revolution are AI agents, intelligent machines that can learn, reason, and          │
# │  interact with their environment. In this article, we will delve into the world of AI agents, exploring what    │
# │  they are, how they work, and their potential applications.                                                     │
# │                                                                                                                 │
# │  What are AI Agents?                                                                                            │
# │  --------------------                                                                                           │
# │                                                                                                                 │
# │  An AI agent is a software program designed to perform tasks that typically require human intelligence, such    │
# │  as decision-making, problem-solving, and learning from experience. Unlike traditional computers, which follow  │
# │  pre-programmed instructions, AI agents use advanced algorithms and machine learning techniques to adapt and    │
# │  improve their performance over time.                                                                           │
# │                                                                                                                 │
# │  Types of AI Agents                                                                                             │
# │  --------------------                                                                                           │
# │                                                                                                                 │
# │  There are several types of AI agents, each with its unique characteristics and capabilities:                   │
# │                                                                                                                 │
# │  *   **Simple Reflex Agents**: These agents react to their environment based on a set of pre-defined rules.     │
# │  They do not learn or improve over time.                                                                        │
# │  *   **Model-Based Reflex Agents**: These agents use a model of the world to reason about the current           │
# │  situation and make decisions.                                                                                  │
# │  *   **Learning Agents**: These agents use machine learning algorithms to learn from experience and improve     │
# │  their performance over time.                                                                                   │
# │  *   **Cognitive Agents**: These agents use advanced techniques such as natural language processing, computer   │
# │  vision, and expert systems to simulate human-like intelligence.                                                │
# │                                                                                                                 │
# │  How AI Agents Work                                                                                             │
# │  -------------------                                                                                            │
# │                                                                                                                 │
# │  AI agents work by using a combination of algorithms and machine learning techniques to process information     │
# │  from their environment. The key steps involved in the operation of an AI agent are:                            │
# │                                                                                                                 │
# │  *   **Perception**: The agent collects data from its environment through sensors, cameras, or other input      │
# │  devices.                                                                                                       │
# │  *   **Reasoning**: The agent uses this data to reason about the current situation and make decisions.          │
# │  *   **Action**: The agent takes actions based on its decisions.                                                │
# │                                                                                                                 │
# │  Applications of AI Agents                                                                                      │
# │  ---------------------------                                                                                    │
# │                                                                                                                 │
# │  AI agents have a wide range of applications across various industries:                                         │
# │                                                                                                                 │
# │  *   **Virtual Assistants**: AI agents are used in virtual assistants such as Siri, Alexa, and Google           │
# │  Assistant to provide personalized support and answer questions.                                                │
# │  *   **Autonomous Vehicles**: AI agents are used in autonomous vehicles to navigate roads, avoid obstacles,     │
# │  and make decisions in real-time.                                                                               │
# │  *   **Robotics**: AI agents are used in robotics to control robots, perform tasks, and interact with their     │
# │  environment.                                                                                                   │
# │  *   **Healthcare**: AI agents are used in healthcare to analyze medical data, diagnose diseases, and provide   │
# │  personalized treatment recommendations.                                                                        │
# │                                                                                                                 │
# │  Challenges and Limitations of AI Agents                                                                        │
# │  -----------------------------------------                                                                      │
# │                                                                                                                 │
# │  While AI agents have shown tremendous potential, they also come with challenges and limitations:               │
# │                                                                                                                 │
# │  *   **Explainability**: It can be difficult to understand the decision-making process of an AI agent.          │
# │  *   **Bias**: AI agents can perpetuate biases present in the data used to train them.                          │
# │  *   **Security**: AI agents can be vulnerable to cyber attacks and data breaches.                              │
# │                                                                                                                 │
# │  Conclusion                                                                                                     │
# │  ----------                                                                                                     │
# │                                                                                                                 │
# │  AI agents are intelligent machines that have the potential to transform various industries. By understanding   │
# │  how they work, their applications, and challenges, we can harness their power to create a better future for    │
# │  humanity. As research continues to advance in this field, we can expect AI agents to become even more          │
# │  sophisticated and capable of performing tasks that were previously thought impossible.                         │
# │                                                                                                                 │
# │  References                                                                                                     │
# │  ----------                                                                                                     │
# │                                                                                                                 │
# │  *   "Artificial Intelligence: A Modern Approach" by Stuart Russell and Peter Norvig                            │
# │  *   "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville                                      │
# │  *   "The Elements of Computing Systems" by Noam Nisan and Shimon Schocken                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 6ae4c63c-8d58-480c-9984-d62d08bc8916                                                                     │
# │  Agent: Senior Technical Writer                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: e26cecfa-ce03-42f1-822c-af798428487e                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: AI Agents: The Future of Intelligent Machines                                                    │
# │  =============================================================                                                  │
# │                                                                                                                 │
# │  Artificial intelligence (AI) has made tremendous progress in recent years, transforming the way we live and    │
# │  work. At the heart of this revolution are AI agents, intelligent machines that can learn, reason, and          │
# │  interact with their environment. In this article, we will delve into the world of AI agents, exploring what    │
# │  they are, how they work, and their potential applications.                                                     │
# │                                                                                                                 │
# │  What are AI Agents?                                                                                            │
# │  --------------------                                                                                           │
# │                                                                                                                 │
# │  An AI agent is a software program designed to perform tasks that typically require human intelligence, such    │
# │  as decision-making, problem-solving, and learning from experience. Unlike traditional computers, which follow  │
# │  pre-programmed instructions, AI agents use advanced algorithms and machine learning techniques to adapt and    │
# │  improve their performance over time.                                                                           │
# │                                                                                                                 │
# │  Types of AI Agents                                                                                             │
# │  --------------------                                                                                           │
# │                                                                                                                 │
# │  There are several types of AI agents, each with its unique characteristics and capabilities:                   │
# │                                                                                                                 │
# │  *   **Simple Reflex Agents**: These agents react to their environment based on a set of pre-defined rules.     │
# │  They do not learn or improve over time.                                                                        │
# │  *   **Model-Based Reflex Agents**: These agents use a model of the world to reason about the current           │
# │  situation and make decisions.                                                                                  │
# │  *   **Learning Agents**: These agents use machine learning algorithms to learn from experience and improve     │
# │  their performance over time.                                                                                   │
# │  *   **Cognitive Agents**: These agents use advanced techniques such as natural language processing, computer   │
# │  vision, and expert systems to simulate human-like intelligence.                                                │
# │                                                                                                                 │
# │  How AI Agents Work                                                                                             │
# │  -------------------                                                                                            │
# │                                                                                                                 │
# │  AI agents work by using a combination of algorithms and machine learning techniques to process information     │
# │  from their environment. The key steps involved in the operation of an AI agent are:                            │
# │                                                                                                                 │
# │  *   **Perception**: The agent collects data from its environment through sensors, cameras, or other input      │
# │  devices.                                                                                                       │
# │  *   **Reasoning**: The agent uses this data to reason about the current situation and make decisions.          │
# │  *   **Action**: The agent takes actions based on its decisions.                                                │
# │                                                                                                                 │
# │  Applications of AI Agents                                                                                      │
# │  ---------------------------                                                                                    │
# │                                                                                                                 │
# │  AI agents have a wide range of applications across various industries:                                         │
# │                                                                                                                 │
# │  *   **Virtual Assistants**: AI agents are used in virtual assistants such as Siri, Alexa, and Google           │
# │  Assistant to provide personalized support and answer questions.                                                │
# │  *   **Autonomous Vehicles**: AI agents are used in autonomous vehicles to navigate roads, avoid obstacles,     │
# │  and make decisions in real-time.                                                                               │
# │  *   **Robotics**: AI agents are used in robotics to control robots, perform tasks, and interact with their     │
# │  environment.                                                                                                   │
# │  *   **Healthcare**: AI agents are used in healthcare to analyze medical data, diagnose diseases, and provide   │
# │  personalized treatment recommendations.                                                                        │
# │                                                                                                                 │
# │  Challenges and Limitations of AI Agents                                                                        │
# │  -----------------------------------------                                                                      │
# │                                                                                                                 │
# │  While AI agents have shown tremendous potential, they also come with challenges and limitations:               │
# │                                                                                                                 │
# │  *   **Explainability**: It can be difficult to understand the decision-making process of an AI agent.          │
# │  *   **Bias**: AI agents can perpetuate biases present in the data used to train them.                          │
# │  *   **Security**: AI agents can be vulnerable to cyber attacks and data breaches.                              │
# │                                                                                                                 │
# │  Conclusion                                                                                                     │
# │  ----------                                                                                                     │
# │                                                                                                                 │
# │  AI agents are intelligent machines that have the potential to transform various industries. By understanding   │
# │  how they work, their applications, and challenges, we can harness their power to create a better future for    │
# │  humanity. As research continues to advance in this field, we can expect AI agents to become even more          │
# │  sophisticated and capable of performing tasks that were previously thought impossible.                         │
# │                                                                                                                 │
# │  References                                                                                                     │
# │  ----------                                                                                                     │
# │                                                                                                                 │
# │  *   "Artificial Intelligence: A Modern Approach" by Stuart Russell and Peter Norvig                            │
# │  *   "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville                                      │
# │  *   "The Elements of Computing Systems" by Noam Nisan and Shimon Schocken                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from IPython.display import Markdown, display

# Si tu as récupéré le résultat dans la variable `result` (ou `response`)
display(Markdown(response.raw))        # ← rend l’article en Markdown joli dans Jupyter/VS Code/Colab
# ou simplement :
print(response.raw)                   # ← version texte brut si tu préfères
# Out:
# AI Agents: The Future of Intelligent Machines
# =============================================================
#
# Artificial intelligence (AI) has made tremendous progress in recent years, transforming the way we live and work. At the heart of this revolution are AI agents, intelligent machines that can learn, reason, and interact with their environment. In this article, we will delve into the world of AI agents, exploring what they are, how they work, and their potential applications.
#
# What are AI Agents?
# --------------------
#
# An AI agent is a software program designed to perform tasks that typically require human intelligence, such as decision-making, problem-solving, and learning from experience. Unlike traditional computers, which follow pre-programmed instructions, AI agents use advanced algorithms and machine learning techniques to adapt and improve their performance over time.
#
# Types of AI Agents
# --------------------
#
# There are several types of AI agents, each with its unique characteristics and capabilities:
#
# *   **Simple Reflex Agents**: These agents react to their environment based on a set of pre-defined rules. They do not learn or improve over time.
# *   **Model-Based Reflex Agents**: These agents use a model of the world to reason about the current situation and make decisions.
# *   **Learning Agents**: These agents use machine learning algorithms to learn from experience and improve their performance over time.
# *   **Cognitive Agents**: These agents use advanced techniques such as natural language processing, computer vision, and expert systems to simulate human-like intelligence.
#
# How AI Agents Work
# -------------------
#
# AI agents work by using a combination of algorithms and machine learning techniques to process information from their environment. The key steps involved in the operation of an AI agent are:
#
# *   **Perception**: The agent collects data from its environment through sensors, cameras, or other input devices.
# *   **Reasoning**: The agent uses this data to reason about the current situation and make decisions.
# *   **Action**: The agent takes actions based on its decisions.
#
# Applications of AI Agents
# ---------------------------
#
# AI agents have a wide range of applications across various industries:
#
# *   **Virtual Assistants**: AI agents are used in virtual assistants such as Siri, Alexa, and Google Assistant to provide personalized support and answer questions.
# *   **Autonomous Vehicles**: AI agents are used in autonomous vehicles to navigate roads, avoid obstacles, and make decisions in real-time.
# *   **Robotics**: AI agents are used in robotics to control robots, perform tasks, and interact with their environment.
# *   **Healthcare**: AI agents are used in healthcare to analyze medical data, diagnose diseases, and provide personalized treatment recommendations.
#
# Challenges and Limitations of AI Agents
# -----------------------------------------
#
# While AI agents have shown tremendous potential, they also come with challenges and limitations:
#
# *   **Explainability**: It can be difficult to understand the decision-making process of an AI agent.
# *   **Bias**: AI agents can perpetuate biases present in the data used to train them.
# *   **Security**: AI agents can be vulnerable to cyber attacks and data breaches.
#
# Conclusion
# ----------
#
# AI agents are intelligent machines that have the potential to transform various industries. By understanding how they work, their applications, and challenges, we can harness their power to create a better future for humanity. As research continues to advance in this field, we can expect AI agents to become even more sophisticated and capable of performing tasks that were previously thought impossible.
#
# References
# ----------
#
# *   "Artificial Intelligence: A Modern Approach" by Stuart Russell and Peter Norvig
# *   "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville
# *   "The Elements of Computing Systems" by Noam Nisan and Shimon Schocken
# AI Agents: The Future of Intelligent Machines
# =============================================================
#
# Artificial intelligence (AI) has made tremendous progress in recent years, transforming the way we live and work. At the heart of this revolution are AI agents, intelligent machines that can learn, reason, and interact with their environment. In this article, we will delve into the world of AI agents, exploring what they are, how they work, and their potential applications.
#
# What are AI Agents?
# --------------------
#
# An AI agent is a software program designed to perform tasks that typically require human intelligence, such as decision-making, problem-solving, and learning from experience. Unlike traditional computers, which follow pre-programmed instructions, AI agents use advanced algorithms and machine learning techniques to adapt and improve their performance over time.
#
# Types of AI Agents
# --------------------
#
# There are several types of AI agents, each with its unique characteristics and capabilities:
#
# *   **Simple Reflex Agents**: These agents react to their environment based on a set of pre-defined rules. They do not learn or improve over time.
# *   **Model-Based Reflex Agents**: These agents use a model of the world to reason about the current situation and make decisions.
# *   **Learning Agents**: These agents use machine learning algorithms to learn from experience and improve their performance over time.
# *   **Cognitive Agents**: These agents use advanced techniques such as natural language processing, computer vision, and expert systems to simulate human-like intelligence.
#
# How AI Agents Work
# -------------------
#
# AI agents work by using a combination of algorithms and machine learning techniques to process information from their environment. The key steps involved in the operation of an AI agent are:
#
# *   **Perception**: The agent collects data from its environment through sensors, cameras, or other input devices.
# *   **Reasoning**: The agent uses this data to reason about the current situation and make decisions.
# *   **Action**: The agent takes actions based on its decisions.
#
# Applications of AI Agents
# ---------------------------
#
# AI agents have a wide range of applications across various industries:
#
# *   **Virtual Assistants**: AI agents are used in virtual assistants such as Siri, Alexa, and Google Assistant to provide personalized support and answer questions.
# *   **Autonomous Vehicles**: AI agents are used in autonomous vehicles to navigate roads, avoid obstacles, and make decisions in real-time.
# *   **Robotics**: AI agents are used in robotics to control robots, perform tasks, and interact with their environment.
# *   **Healthcare**: AI agents are used in healthcare to analyze medical data, diagnose diseases, and provide personalized treatment recommendations.
#
# Challenges and Limitations of AI Agents
# -----------------------------------------
#
# While AI agents have shown tremendous potential, they also come with challenges and limitations:
#
# *   **Explainability**: It can be difficult to understand the decision-making process of an AI agent.
# *   **Bias**: AI agents can perpetuate biases present in the data used to train them.
# *   **Security**: AI agents can be vulnerable to cyber attacks and data breaches.
#
# Conclusion
# ----------
#
# AI agents are intelligent machines that have the potential to transform various industries. By understanding how they work, their applications, and challenges, we can harness their power to create a better future for humanity. As research continues to advance in this field, we can expect AI agents to become even more sophisticated and capable of performing tasks that were previously thought impossible.
#
# References
# ----------
#
# *   "Artificial Intelligence: A Modern Approach" by Stuart Russell and Peter Norvig
# *   "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville
# *   "The Elements of Computing Systems" by Noam Nisan and Shimon Schocken

# %% [markdown]
# ## Intégration d'outils

# %%
f = open("output.md", "w")
f.write(response.raw)
f.close()

# %%
# Définissons d'outils de lecture
from crewai_tools import FileReadTool

file_read_tool = FileReadTool()

# %%
summarizer_agent = Agent(
    role="Senior Document Summarizer",
    goal="Extract and summarize key insights from provided files in 20 words or less.",
    backstory="""You are an expert in document analysis, skilled at extracting 
                 key details, summarizing content, and identifying critical 
                 insights from structured and unstructured text.""",
    tools=[file_read_tool],
    llm=llm,
    verbose=True
)

# %%
summarizer_task = Task(
    description=(
        "Use the FileReadTool to read the contents of {file_path}"
        "and provide a summary in 20 words or less. "
        "Ensure the summary captures the key insights "
        "and main points from the document."
    ),
    agent=summarizer_agent,
    tools=[file_read_tool],
    expected_output="A concise 20-word summary of the key points from the file.",
)

# %%
from crewai import Crew
summarizer_crew = Crew(
    agents=[summarizer_agent],
    tasks=[summarizer_task],
    verbose=True
)

# Run the crew with the file input
result = summarizer_crew.kickoff(inputs={"file_path": "C:\\Users\\Utilisateur\\Desktop\\BE\\Fichiers\\Les_projets\\AI_agents_Courses\\Partie1\\Agentic_system101\\output.md"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 7a980713-cff6-4285-801e-80300f9d6eab                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Document Summarizer                                                                              │
# │                                                                                                                 │
# │  Task: Use the FileReadTool to read the contents of                                                             │
# │  C:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\Partie1\Agentic_system101\output.mdand  │
# │  provide a summary in 20 words or less. Ensure the summary captures the key insights and main points from the   │
# │  document.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Document Summarizer                                                                              │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Thought: I need to summarize the contents of the output.md file                                                │
# │  Action: { 'file_path': {'description':                                                                         │
# │  'C:\\Users\\Utilisateur\\Desktop\\BE\\Fichiers\\Les_projets\\AI_agents_Courses\\Partie1\\Agentic_system101\\o  │
# │  utput.md', 'type': 'str'}, 'start_line': {'description': '1', 'type': 'UnionType[int, NoneType]'},             │
# │  'line_count': {'description': 'None', 'type': 'UnionType[int, NoneType]'}}                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 7a980713-cff6-4285-801e-80300f9d6eab                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Thought: I need to summarize the contents of the output.md file                                  │
# │  Action: { 'file_path': {'description':                                                                         │
# │  'C:\\Users\\Utilisateur\\Desktop\\BE\\Fichiers\\Les_projets\\AI_agents_Courses\\Partie1\\Agentic_system101\\o  │
# │  utput.md', 'type': 'str'}, 'start_line': {'description': '1', 'type': 'UnionType[int, NoneType]'},             │
# │  'line_count': {'description': 'None', 'type': 'UnionType[int, NoneType]'}}                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: e35e43f7-4b96-4a90-a757-e5ed2f03963b                                                                     │
# │  Agent: Senior Document Summarizer                                                                              │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# # Multi Agent

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from crewai_tools import SerperDevTool

serper_dev_tool = SerperDevTool()

# %%
from crewai import Agent, Task

research_agent = Agent(
    role="Internet Researcher",
    goal="Find the most relevant and recent information about a given topic.",
    backstory="""You are a skilled researcher, adept at navigating the internet 
                 and gathering high-quality, reliable information.""",
    tools=[serper_dev_tool],
    llm=llm,
    allow_delegation=False,
    max_iterations=3,
    verbose=True
)

research_task = Task(
    description="""Use the SerperDevTool to search for the 
                   most relevant and recent data about {topic}."""
                "Extract the key insights from multiple sources.",
    agent=research_agent,
    tools=[serper_dev_tool],
    expected_output="A detailed research report with key insights and source references.",
    max_iterations=2,
)

# %%
summarizer_agent = Agent(
    role="Content Summarizer",
    goal="Condense the key insights from research into a short and informative summary.",
    backstory="""You are an expert in distilling complex information into concise, 
                 easy-to-read summaries.""",
    llm=llm,
    allow_delegation=False,
    verbose=True
)

summarization_task = Task(
    description="Summarize the research report into a concise and informative paragraph. "
                "Ensure clarity, coherence, and completeness.",
    agent=summarizer_agent,
    expected_output="A well-structured summary with the most important insights."
)

# %%
fact_checker_agent = Agent(
    role="Fact-Checking Specialist",
    goal="Verify the accuracy of information and remove any misleading or false claims.",
    backstory="""You are an investigative journalist with a knack for validating facts, 
                 ensuring that only accurate information is published.""",
    tools=[serper_dev_tool],
    llm=llm,
    allow_delegation=False,
    verbose=True
)

fact_checking_task = Task(
    description="Verify the summarized information for accuracy using the SerperDevTool. "
                "Cross-check facts with reliable sources and correct any errors.",
    agent=fact_checker_agent,
    tools=[serper_dev_tool],
    expected_output="A fact-checked, verified summary of the research topic."
)

# %%
from crewai import Crew, Process

research_crew = Crew(
    agents=[research_agent, summarizer_agent, fact_checker_agent],
    tasks=[research_task, summarization_task, fact_checking_task],
    process=Process.sequential,
    verbose=True,
    max_rpm=50
)

result = research_crew.kickoff(inputs={"topic": "The impact of AI on job markets"})
print("\nFinal Verified Summary:\n", result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 804cdf48-239f-44b4-9c1b-c4f5b02b7ebe                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Task: Use the SerperDevTool to search for the                                                                  │
# │                     most relevant and recent data about The impact of AI on job markets.Extract the key         │
# │  insights from multiple sources.                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I need to search for recent data about The impact of AI on job markets                       │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "The impact of AI on job markets 2024"                                                       │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'The impact of AI on job markets 2024', 'type': 'search', 'num': 10, 'engine':      │
# │  'google'}, 'organic': [{'title': '[PDF] Artificial Intelligence Impact on Labor Markets', 'link':              │
# │  'https://www.iedconline.org/clientuploads/EDRP%20Logos/AI_Impact_on_Labor_Markets.pdf', 'snippet': "One of     │
# │  the primary concerns surrounding AI's impact on the labor market is the potential for widespread job           │
# │  displacement and automation. A ...", 'position': 1}, {'title': 'Evaluating the Impact of AI on the Labor       │
# │  Market - Yale Budget Lab', 'link':                                                                             │
# │  'https://budgetlab.yale.edu/research/evaluating-impact-ai-labor-market-current-state-affairs', 'snippet':      │
# │  "Overall, our metrics indicate that the broader labor market has not experienced a discernible disruption      │
# │  since ChatGPT's release 33 months ago, ...", 'position': 2}, {'title': "AI's Impact on Job Growth | J.P.       │
# │  Morgan Global Research", 'link':                                                                               │
# │  'https://www.jpmorgan.com/insights/global-research/artificial-intelligence/ai-impact-job-growth', 'snippet':   │
# │  'August 15, 2025. AI is poised to displace jobs, with some industries more at risk than others. Is the         │
# │  paradigm shift already underway?', 'position': 3}, {'title': 'Jobs AI Will Replace First in the Workplace      │
# │  Shift - Forbes', 'link':                                                                                       │
# │  'https://www.forbes.com/sites/jackkelly/2025/04/25/the-jobs-that-will-fall-first-as-ai-takes-over-the-workpla  │
# │  ce/', 'snippet': 'By 2040, AI will likely automate or transform 50% to 60% of jobs, with full dominance (80%   │
# │  and higher) possible by 2050, assuming steady innovation.', 'position': 4}, {'title': 'What impact is          │
# │  artificial intelligence having on the U.S. labor market ...', 'link':                                          │
# │  'https://equitablegrowth.org/what-impact-is-artificial-intelligence-having-on-the-u-s-labor-market-and-the-na  │
# │  tions-economy/', 'snippet': 'AI could produce a workplace where jobs are broken up by task and translated      │
# │  into roles closer to those considered part of the gig economy today ...', 'position': 5}, {'title': 'Is AI     │
# │  closing the door on entry-level job oppo...                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I need to extract key insights from the search results                                       │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I need to analyze the key insights from the search results                                   │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Thought: Thought: I need to analyze the key insights from the search results and provide a detailed research   │
# │  report with source references.                                                                                 │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The impact of AI on job markets in 2024 is a complex and multifaceted issue. While some jobs may be            │
# │  displaced, others may be created or become more valuable due to automation. However, there is no clear         │
# │  evidence to support the idea that AI will replace 50% of all jobs within the next five years. Instead, AI is   │
# │  likely to augment certain tasks and make workers more productive, leading to increased company growth in       │
# │  revenue, profits, employment, and profitability. The key is for workers to develop new skills to remain        │
# │  relevant in an increasingly automated job market.                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 051651ac-5aac-4052-b686-ce9cd246e590                                                                     │
# │  Agent: Internet Researcher                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Summarizer                                                                                      │
# │                                                                                                                 │
# │  Task: Summarize the research report into a concise and informative paragraph. Ensure clarity, coherence, and   │
# │  completeness.                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Summarizer                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  While some jobs may be displaced by AI, others will be created or become more valuable due to automation.      │
# │  However, there is no clear evidence that AI will replace 50% of all jobs within the next five years. Instead,  │
# │  AI is likely to augment certain tasks and make workers more productive, leading to increased company growth    │
# │  in revenue, profits, employment, and profitability. The key for workers is to develop new skills to remain     │
# │  relevant in an increasingly automated job market, where AI's impact will vary across industries and            │
# │  occupations, with some jobs being highly susceptible to automation while others will be less affected or even  │
# │  become more valuable due to the increased efficiency and productivity brought by AI.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 0979c5f5-9d6b-4104-bfe1-e28f80c23cb7                                                                     │
# │  Agent: Content Summarizer                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
