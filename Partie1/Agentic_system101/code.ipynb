# %% [markdown]
# ## Modular crew

# %%
from research_crew import ResearchCrew

research_crew = ResearchCrew()

result = research_crew.crew().kickoff(inputs={"topic": "The impact of AI on job markets"})
# Out:
# WARNING:root:File not found: c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\Partie1\Agentic_system101\Partie1\Agentic_system101\config\agents.yaml
# WARNING:root:Agent config file not found at c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\Partie1\Agentic_system101\Partie1\Agentic_system101\config\agents.yaml. Proceeding with empty agent configurations.
# WARNING:root:File not found: c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\Partie1\Agentic_system101\Partie1\Agentic_system101\config\tasks.yaml
# WARNING:root:Task config file not found at c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\Partie1\Agentic_system101\Partie1\Agentic_system101\config\tasks.yaml. Proceeding with empty task configurations.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 5
#       1 from research_crew import ResearchCrew
#       3 research_crew = ResearchCrew()
# ----> 5 result = research_crew.crew().kickoff(inputs={"topic": "The impact of AI on job markets"})
#
# File c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\env\lib\site-packages\crewai\project\utils.py:70, in _memoize_sync.<locals>.wrapper(*args, **kwargs)
#      67 if cached_result is not None:
#      68     return cached_result
# ---> 70 result = meth(*args, **kwargs)
#      71 cache.add(tool=meth.__name__, input=cache_key, output=result)
#      72 return result
#
# File c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\env\lib\site-packages\crewai\project\annotations.py:220, in crew.<locals>.wrapper(self, *args, **kwargs)
#     218 # Instantiate tasks in order
#     219 for _, task_method in tasks:
# --> 220     task_instance = _call_method(task_method, self)
#     221     instantiated_tasks.append(task_instance)
#     222     agent_instance = getattr(task_instance, "agent", None)
#
# File c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\env\lib\site-packages\crewai\project\annotations.py:163, in _call_method(method, *args, **kwargs)
#     161 def _call_method(method: Callable[..., Any], *args: Any, **kwargs: Any) -> Any:
#     162     """Call a method, awaiting it if async and running in an event loop."""
# --> 163     result = method(*args, **kwargs)
#     164     if inspect.iscoroutine(result):
#     165         try:
#
# File c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\env\lib\site-packages\crewai\project\wrappers.py:319, in TaskMethod.__call__(self, *args, **kwargs)
#     309 def __call__(self, *args: P.args, **kwargs: P.kwargs) -> TaskResultT:
#     310     """Call the wrapped method and set task name if not provided.
#     311
#     312     Args:
#    (...)
#     317         The task instance with name set if not already provided.
#     318     """
# --> 319     result = self._meth(*args, **kwargs)
#     320     result = _resolve_result(result)
#     321     return self.ensure_task_name(result)
#
# File c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\env\lib\site-packages\crewai\project\utils.py:70, in _memoize_sync.<locals>.wrapper(*args, **kwargs)
#      67 if cached_result is not None:
#      68     return cached_result
# ---> 70 result = meth(*args, **kwargs)
#      71 cache.add(tool=meth.__name__, input=cache_key, output=result)
#      72 return result
#
# File c:\Users\Utilisateur\Desktop\BE\Fichiers\Les_projets\AI_agents_Courses\Partie1\Agentic_system101\research_crew.py:40, in ResearchCrew.research_task(self)
#      37 @task
#      38 def research_task(self) -> Task:
#      39     return Task(
# ---> 40         config=self.tasks_config['research_task'],
#      41         tools=[self.search_tool],
#      42     )
#
# KeyError: 'research_task'
